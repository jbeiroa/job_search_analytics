# %% [markdown]
# # Data Analytics on my Job Search

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('job_applications_final.csv')
data.head()
# Out:
#   application_date          company                          job_title  \
# 0       2026-04-24        AI Report                     AI/ML Engineer
# 1       2026-04-28  ASAP Consulting  ML/AI Engineer and Data Scientist
# 2       2026-04-28  ASAP Consulting    ML/AI Engineer y Data Scientist
# 3       2026-03-25        Accenture                      Academy Sr AI
# 4       2026-04-27        Accenture              Consulting Specialist
#
#        platform response_date response_status
# 0      LinkedIn    2026-04-24        Received
# 1  Direct Email           NaN        Received
# 2  Direct Email           NaN        Received
# 3  Direct Email    2026-03-25        Received
# 4      LinkedIn    2026-04-27        Received

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   application_date  275 non-null    str
#  1   company           278 non-null    str
#  2   job_title         247 non-null    str
#  3   platform          278 non-null    str
#  4   response_date     134 non-null    str
#  5   response_status   278 non-null    str
# dtypes: str(6)
# memory usage: 13.2 KB

# %%
data["application_date"] = pd.to_datetime(data["application_date"], format="mixed")
data["response_date"] = pd.to_datetime(data["response_date"], errors='coerce')
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   application_date  275 non-null    datetime64[us]
#  1   company           278 non-null    str
#  2   job_title         247 non-null    str
#  3   platform          278 non-null    str
#  4   response_date     133 non-null    datetime64[us]
#  5   response_status   278 non-null    str
# dtypes: datetime64[us](2), str(4)
# memory usage: 13.2 KB

# %%
data.response_status.value_counts()
# Out:
# response_status
# Received           194
# No Response         47
# Rejected            23
# Interview            5
# Technical Test       4
# Update Received      2
# In Progress          1
# Questionnaire        1
# Not Applicable       1
# Name: count, dtype: int64

# %%
repeated = (data.job_title.isna() & data.duplicated(subset="company"))

# %%
data = data[~repeated]

# %%
data.query('response_status != "Received" & response_date.isna()')
# Out:
#     application_date             company  \
# 6         2026-04-20           Accenture
# 19        2026-04-20               AceUp
# 27        2026-04-20           Anyone AI
# 35        2026-04-26                BYMA
# 41        2026-04-27         Banco Macro
# 44        2026-04-27             Beeflow
# 58        2026-04-29             Bumeran
# 61        2026-04-20              Canals
# 71        2026-04-20      Central Puerto
# 78        2026-04-20               Cocos
# 112       2026-04-29             Dev.Pro
# 113       2026-04-20              DevRev
# 115       2026-04-20             Dialpad
# 121       2026-04-27        EPAM Systems
# 129       2026-04-01             Experis
# 148       2026-04-07       INDI Staffing
# 154       2026-04-20     ITSM Consulting
# 158       2026-04-20            Innodata
# 165       2026-04-21            JPMorgan
# 177       2026-04-08  Laboratorios Jayor
# 181       2026-04-25              Marval
# 184       2026-04-20       Mercado Libre
# ...

# %%
data.query('response_status == "Received"')
# Out:
#     application_date          company                          job_title  \
# 0         2026-04-24        AI Report                     AI/ML Engineer
# 1         2026-04-28  ASAP Consulting  ML/AI Engineer and Data Scientist
# 2         2026-04-28  ASAP Consulting    ML/AI Engineer y Data Scientist
# 3         2026-03-25        Accenture                      Academy Sr AI
# 4         2026-04-27        Accenture              Consulting Specialist
# ..               ...              ...                                ...
# 268       2026-02-05          Xometry       Machine Learning Engineer II
# 270       2026-04-26     Y Combinator            Job Title Not Specified
# 271       2026-03-13         Yumatech                       Data Analyst
# 272       2026-04-29             belo                               Juan
# 273       2026-04-20          hiberus                        IA Engineer
#
#          platform response_date response_status
# ...
